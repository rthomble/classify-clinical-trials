# %% [markdown]
# ## Optional Homework #1 (for the updated JSON file)
#
# For anyone looking to try out their skills, try one or all of these exercises:
#
# Start with the data file: "NEW_clinical_trial_data.json" DO NOT USE the in-memory version of the data, as generated by the Jupyter Notebook "Clinical Trial Data Extraction.ipynb"
#
# The data structure used by clinicaltrials.ucsf.edu needs a number of fields and formatting choices that are important for keeping their webpage operational, but aren't ideal for our needs. However, if we want our modeling work to be useful, we need a way to easily join the outcome of our NLP model to the production JSON data structure.  The production data structure is a dictionary of dictionaries, with the primary key being the clinical trial "nct_number": an 11 digit unique identifier beginning with the string "NCT" (ie - 'NCT12345678').  Our NLP data structure, should therefore also be indexed by this identifier.
#
# Additionally, only certain trials are visible on the website, so we will need to know which trials are considered "visible" and "joinable", so we can appropriately categorize only the visible trials. The variable names in the JSON are 'is_joinable' and 'is_visible.'
#
# #### Exercise 1
# Your first task is to build a smaller test dataset that removes some of the fields we do not care about. Create a new data structure, and for each trial, copy over only the data that you believe would be useful as inputs to our model (plus the variables mentioned above) and save it to disk. Remember that modeling works best when we focus on the details that change appreciable between our unit of analysis (ie - trials.) In other words, your choise of variables to retain should not be things like "sponsor" or "recruitment status" because they won't really contribute much to our models.
#
# #### Exercise 2
# Many of the most interesting fields (like 'summary') are riddled with formatting characters. This is great for hosting a website, but it is just noise for our NLP work.  For each of the free-text fields you've extracted in Exercise 1, remove all of the HTML formatting (Hint: The python package BeautifulSoup can be very useful here!).
#
# #### Exercise 2a
# If you'd like to extend excercise 2, it would be useful to use Spacy/NLTK or something else to break the free text sections from excercise 2 into individual sentences and store them as elements in a list.
#
# #### Exercise 3
# Our goal for our modeling project is to categorize each of the trials into a unique category.  The language of clinicaltrials.ucsf.edu defines "clusters" as the primary category, and "conditions" as the sub-category.  Each trial can be classified as relating to multiple "conditions", and each condition can belong to multiple "clusters." This complicates our modeling task appreciably. To simplify our project, we will assume that all "conditions" are adequately assigned (not a bad assumption, there are very few conditions = "other") and we will assume that any clincical trial that has at least 1 "cluster" not equal to "Other" can be categorized into that non-other cluster.  In other words, we are only interested in classifying trials that cannot be otherwise categorized.
#
# For exercise 3, please create a field in our data structure that indicates whether a specific trial has ONLY "other" clusters (even if there are more than 1).

# %% [markdown]
# ## Exercise 1

# %%
import json

# %%
with open("/Users/rthombley/Downloads/__data_export.json", 'rb') as ct_raw:
    jdata = json.load(ct_raw)

# %% [markdown]
# Let's start by exploring some of the data.
# We can start by printing out the 1st 10 keys to the jdata dictionary (these are the NCT codes)

# %%
[x for x in jdata.keys()][1:10]
# Out:
# ['NCT00000134',
#  'NCT00000136',
#  'NCT00000139',
#  'NCT00000142',
#  'NCT00000143',
#  'NCT00000168',
#  'NCT00000173',
#  'NCT00000409',
#  'NCT00000410']

# %% [markdown]
# Now let's choose a random key, and inspect the dictionary contents.

# %%
jdata['NCT00000134']
# Out:
# {'completion_date': '1995-03-01',
#  'conditions': [{'clusters': ['Infectious Diseases'],
#    'name': 'HIV/AIDS',
#    'slug': 'hiv-aids'},
#   {'clusters': ['Other'],
#    'name': 'Cytomegalovirus Retinitis',
#    'slug': 'cytomegalovirus-retinitis'}],
#  'description_html': '<p>CMV retinitis is the most common intraocular infection in patients with AIDS and is estimated to affect 35 to 40 percent of patients with AIDS. Untreated CMV retinitis is a progressive disorder, the end result of which is total retinal destruction and blindness. At the time of this trial, drugs approved by the United States Food and Drug Administration (FDA) for the treatment of CMV retinitis were ganciclovir (Cytovene) and foscarnet (Foscavir). Although most retinitis responds well to initial therapy with systemically administered drugs, given enough time, nearly all patients will suffer a relapse of the retinitis. Relapsed retinitis generally responds to reinduction and maintenance therapy, but the interval between successive relapses progressively shortens. The CRRT addressed the issue of the management of relapsed CMV retinitis.</p>\n\n<p>The CRRT was a multicenter, randomized, controlled clinical trial comparing three regimens in patients with relapsed retinitis. Patients with AIDS and CMV retinitis that had relapsed or was nonresponsive to initial therapy were randomized to one of three regimens: (1) intravenous foscarnet reinduction at 90 mg/kg twice daily for 2 weeks, followed by maintenance therapy at 120 mg/kg/day; (2) intravenous ganciclovir reinduction at 5 mg/kg twice daily for 2 weeks followed by maintenance at 10 mg/kg/day; and (3) combination therapy, wherein patients continued their previous therapy and were reinduced with the second drug and then placed on maintenance therapy with foscarnet at 90 mg/kg/day and ganciclovir at 5 mg/kg/day.</p>',
#  'eligibility_by_age_open_to_18_and_over': True,
#  'eligibility_by_age_open_to_under_18': False,
#  'eligibility_by_sex_all': True,
#  'eligibility_by_sex_female': True,
#  'eligibility_by_sex_male': True,
#  'eligibility_exclusion_html': '<p> history of intolerance to ganciclovir or foscarnet, history of therapy\n  involving the combination of foscarnet and ganciclovir, unwillingness to practice\n  appropriate birth control, active drug or alcohol abuse, media opacity, retinal detachment\n  not scheduled for surgical repair</p>',
#  'eligibility_healthy_volunteers': False,
#  'eligibility_html': '<p>  inclusion criteria: Males and females eligible for the CRRT must have been age 18 years or\n  older and have had AIDS and CMV retinitis. They must have had active CMV despite a minimum\n  of 28 days of previous treatment with an anti-CMV drug. Furthermore, they must have had an\n  absolute neutrophil count greater than or equal to 500 cells/µL, platelet count greater\n  than or equal to 20,000 cells/µL, and a serum creatinine &lt; 2.5 mg/dL in order to tolerate\n  the drug regimens.</p>\n\n<p>exclusion criteria: history of intolerance to ganciclovir or foscarnet, history of therapy\n  involving the combination of foscarnet and ganciclovir, unwillingness to practice\n  appropriate birth control, active drug or alcohol abuse, media opacity, retinal detachment\n  not scheduled for surgical repair</p>',
#  'eligibility_inclusion_html': '<p> Males and females eligible for the CRRT must have been age 18 years or\n  older and have had AIDS and CMV retinitis. They must have had active CMV despite a minimum\n  of 28 days of previous treatment with an anti-CMV drug. Furthermore, they must have had an\n  absolute neutrophil count greater than or equal to 500 cells/µL, platelet count greater\n  than or equal to 20,000 cells/µL, and a serum creatinine &lt; 2.5 mg/dL in order to tolerate\n  the drug regimens.</p>',
#  'eligibility_summary_short': 'people ages 18 years and up',
#  'eligibility_tags': [],
#  'estimated_completion_date': None,
#  'id': 'NCT00000134',
#  'institution_names': ['UCSF'],
#  'institutional_pis': [],
#  'institutions': ['ucsf'],
#  'is_contactable': False,
#  'is_contactable_matches_studywide_status': True,
#  'is_joinable': False,
#  'is_joinable_matches_studywide_status': True,
#  'is_visible': False,
#  'is_visible_matches_studywide_status': True,
#  'json_ld': None,
#  'keywords': ['HIV Infections',
#   'Acquired Immunodeficiency Syndrome',
#   'Cytomegalovirus Retinitis',
#   'Immunologic Deficiency Syndromes',
#   'Retinitis',
#   'Ganciclovir',
#   'Foscarnet',
#   'Phosphonoacetic Acid',
#   'Ganciclovir triphosphate',
#   'intravenous foscarnet',
#   'intravenous ganciclovir'],
#  'last_changed_or_verified_date': '2015-08-11',
#  'links': [{'description': 'NEI Press Release-Two Drug Treatment Is Effective Against Recurrent Eye Infection In AIDS Patients',
#    'url': 'http://www.nei.nih.gov/news/pressreleases/crrtpressrelease.asp'}],
#  'locations': [],
#  'nct_number': 'NCT00000134',
#  'phase': '3',
#  'phase_1': False,
#  'phase_2': False,
#  'phase_3': True,
#  'phase_4': False,
#  'phase_unspecified': False,
#  'recruitment_status': 'Completed',
#  'recruitment_status_schema_dot_org': 'Completed',
#  'source': 'Johns Hopkins Bloomberg School of Public Health',
#  'sponsor': 'Johns Hopkins Bloomberg School of Public Health',
#  'start_date': '1992-12-01',
#  'study_type': 'Interventional',
#  'summary': 'To compare the relative merits of three therapeutic regimens in patients with AIDS and CMV retinitis who have been previously treated but whose retinitis either is nonresponsive or has relapsed. These three therapeutic regimens were (1) foscarnet, (2) high-dose ganciclovir, and (3) combination foscarnet and ganciclovir. To compare two treatment strategies in patients with relapsed or nonresponsive CMV retinitis: (1) continuing the same anti-CMV drug or (2) switching to the alternate drug.',
#  'summary_html': '<p>To compare the relative merits of three therapeutic regimens in patients with AIDS and CMV retinitis who have been previously treated but whose retinitis either is nonresponsive or has relapsed. These three therapeutic regimens were (1) foscarnet, (2) high-dose ganciclovir, and (3) combination foscarnet and ganciclovir. To compare two treatment strategies in patients with relapsed or nonresponsive CMV retinitis: (1) continuing the same anti-CMV drug or (2) switching to the alternate drug.</p>',
#  'title_brief': 'Studies of the Ocular Complications of AIDS (SOCA)--Cytomegalovirus Retinitis Retreatment Trial (CRRT)',
#  'title_official': 'Cytomegalovirus Retinitis Retreatment Trial',
#  'title_tagline': None,
#  'visits_description': None}

# %% [markdown]
# Ok - so, looking through this, I think I want to use the following elements in our analytic dataset:
# * The raw condition tree
# * description_html
# * eligibility_by_age_open_to_18_and_over
# * eligibility_by_age_open_under_18
# * eligibility_by_sex_all
# * eligibility_by_sex_female
# * eligibility_by_sex_male
# * eligibility_exclusion_html
# * eligibility_inclusion_html
# * eligibility_healthy_volunteers
# * eligibility_tags
# * is_joinable
# * is_visible
# * keywords
# * summary
# * title_brief
# * title_official
#
# From these elements, I'll also create a few derived elements:
# * Parsed conditions & cluster lists
# * Assigned category label
# * on_website flag
# * pediatric flag
# * adult flag
# * female only flag
# * male only flag
# * lists for the parsed tokens
#
# So, let's begin by extracting the elements of interest

# %%
elements_of_interest = ['conditions','description_html', 'eligibility_by_age_open_to_18_and_over','eligibility_by_age_open_under_18',
                       'eligibility_by_sex_all','eligibility_by_sex_female','eligibility_by_sex_male',
                       'eligibility_exclusion_html','eligibility_inclusion_html','eligibility_healthy_volunteers',
                       'eligibility_tags','is_joinable','is_visible','keywords','summary','title_brief','title_official']
analytic_data = {}
for nct in jdata.keys():
    analytic_data[nct] = {k:jdata[nct][k] for k in jdata[nct].keys() if k in elements_of_interest}

# %% [markdown]
# Now we've built our dictionary subset, let's take a look at what we've got:

# %%
analytic_data['NCT00000134']
# Out:
# {'conditions': [{'clusters': ['Infectious Diseases'],
#    'name': 'HIV/AIDS',
#    'slug': 'hiv-aids'},
#   {'clusters': ['Other'],
#    'name': 'Cytomegalovirus Retinitis',
#    'slug': 'cytomegalovirus-retinitis'}],
#  'description_html': '<p>CMV retinitis is the most common intraocular infection in patients with AIDS and is estimated to affect 35 to 40 percent of patients with AIDS. Untreated CMV retinitis is a progressive disorder, the end result of which is total retinal destruction and blindness. At the time of this trial, drugs approved by the United States Food and Drug Administration (FDA) for the treatment of CMV retinitis were ganciclovir (Cytovene) and foscarnet (Foscavir). Although most retinitis responds well to initial therapy with systemically administered drugs, given enough time, nearly all patients will suffer a relapse of the retinitis. Relapsed retinitis generally responds to reinduction and maintenance therapy, but the interval between successive relapses progressively shortens. The CRRT addressed the issue of the management of relapsed CMV retinitis.</p>\n\n<p>The CRRT was a multicenter, randomized, controlled clinical trial comparing three regimens in patients with relapsed retinitis. Patients with AIDS and CMV retinitis that had relapsed or was nonresponsive to initial therapy were randomized to one of three regimens: (1) intravenous foscarnet reinduction at 90 mg/kg twice daily for 2 weeks, followed by maintenance therapy at 120 mg/kg/day; (2) intravenous ganciclovir reinduction at 5 mg/kg twice daily for 2 weeks followed by maintenance at 10 mg/kg/day; and (3) combination therapy, wherein patients continued their previous therapy and were reinduced with the second drug and then placed on maintenance therapy with foscarnet at 90 mg/kg/day and ganciclovir at 5 mg/kg/day.</p>',
#  'eligibility_by_age_open_to_18_and_over': True,
#  'eligibility_by_sex_all': True,
#  'eligibility_by_sex_female': True,
#  'eligibility_by_sex_male': True,
#  'eligibility_exclusion_html': '<p> history of intolerance to ganciclovir or foscarnet, history of therapy\n  involving the combination of foscarnet and ganciclovir, unwillingness to practice\n  appropriate birth control, active drug or alcohol abuse, media opacity, retinal detachment\n  not scheduled for surgical repair</p>',
#  'eligibility_healthy_volunteers': False,
#  'eligibility_inclusion_html': '<p> Males and females eligible for the CRRT must have been age 18 years or\n  older and have had AIDS and CMV retinitis. They must have had active CMV despite a minimum\n  of 28 days of previous treatment with an anti-CMV drug. Furthermore, they must have had an\n  absolute neutrophil count greater than or equal to 500 cells/µL, platelet count greater\n  than or equal to 20,000 cells/µL, and a serum creatinine &lt; 2.5 mg/dL in order to tolerate\n  the drug regimens.</p>',
#  'eligibility_tags': [],
#  'is_joinable': False,
#  'is_visible': False,
#  'keywords': ['HIV Infections',
#   'Acquired Immunodeficiency Syndrome',
#   'Cytomegalovirus Retinitis',
#   'Immunologic Deficiency Syndromes',
#   'Retinitis',
#   'Ganciclovir',
#   'Foscarnet',
#   'Phosphonoacetic Acid',
#   'Ganciclovir triphosphate',
#   'intravenous foscarnet',
#   'intravenous ganciclovir'],
#  'summary': 'To compare the relative merits of three therapeutic regimens in patients with AIDS and CMV retinitis who have been previously treated but whose retinitis either is nonresponsive or has relapsed. These three therapeutic regimens were (1) foscarnet, (2) high-dose ganciclovir, and (3) combination foscarnet and ganciclovir. To compare two treatment strategies in patients with relapsed or nonresponsive CMV retinitis: (1) continuing the same anti-CMV drug or (2) switching to the alternate drug.',
#  'title_brief': 'Studies of the Ocular Complications of AIDS (SOCA)--Cytomegalovirus Retinitis Retreatment Trial (CRRT)',
#  'title_official': 'Cytomegalovirus Retinitis Retreatment Trial'}

# %% [markdown]
# #### Exercise 2
# Now that we've subset our dataset, let's start cleaning it up a little bit. There are 4 immediately obvious things wrong with the HTML fields, for our purposes.
# 1. There are HTML tags (`<p>`). We will strip this with a regular expression.
# 2. There are new line characters (`\n`). We will strip this also with a regex.
# 3. There are HTML character entities (`&Lt;`). These exist because the carat characters (<,>) are reserved characters in HTML, so they have to be escaped in well formatted HTML. The html library has the unescape() method which converts these character entities to their unicode equivalents.
# 4. Lastly, we need to normalize all of the spaces (ie - multiple spaces are replaced by a single space).

# %%
import re
import html
find_html = re.compile(r'<.*?>')
find_spaces = re.compile(r'\s{2,+}')
def removeHTML(raw_html):
    cleantext = re.sub(find_html, '', raw_html)
    cleantext = re.sub('\n','',cleantext)
    cleantext = html.unescape(cleantext)
    cleantext = re.sub(find_spaces, ' ', cleantext)
    return cleantext.strip()
# Test it out:
html_test = "<html><head></head><h2>Hello\n world!</h2>"
print(removeHTML(html_test))
# Out:
# Hello world!

# %%
elements_with_html = ['description_html','eligibility_exclusion_html','eligibility_inclusion_html']

for trial in analytic_data.keys():
    for element in elements_with_html:
        analytic_data[trial][element] = removeHTML(analytic_data[trial][element])

# %%
analytic_data['NCT00000134']
# Out:
# {'conditions': [{'clusters': ['Infectious Diseases'],
#    'name': 'HIV/AIDS',
#    'slug': 'hiv-aids'},
#   {'clusters': ['Other'],
#    'name': 'Cytomegalovirus Retinitis',
#    'slug': 'cytomegalovirus-retinitis'}],
#  'description_html': 'CMV retinitis is the most common intraocular infection in patients with AIDS and is estimated to affect 35 to 40 percent of patients with AIDS. Untreated CMV retinitis is a progressive disorder, the end result of which is total retinal destruction and blindness. At the time of this trial, drugs approved by the United States Food and Drug Administration (FDA) for the treatment of CMV retinitis were ganciclovir (Cytovene) and foscarnet (Foscavir). Although most retinitis responds well to initial therapy with systemically administered drugs, given enough time, nearly all patients will suffer a relapse of the retinitis. Relapsed retinitis generally responds to reinduction and maintenance therapy, but the interval between successive relapses progressively shortens. The CRRT addressed the issue of the management of relapsed CMV retinitis.The CRRT was a multicenter, randomized, controlled clinical trial comparing three regimens in patients with relapsed retinitis. Patients with AIDS and CMV retinitis that had relapsed or was nonresponsive to initial therapy were randomized to one of three regimens: (1) intravenous foscarnet reinduction at 90 mg/kg twice daily for 2 weeks, followed by maintenance therapy at 120 mg/kg/day; (2) intravenous ganciclovir reinduction at 5 mg/kg twice daily for 2 weeks followed by maintenance at 10 mg/kg/day; and (3) combination therapy, wherein patients continued their previous therapy and were reinduced with the second drug and then placed on maintenance therapy with foscarnet at 90 mg/kg/day and ganciclovir at 5 mg/kg/day.',
#  'eligibility_by_age_open_to_18_and_over': True,
#  'eligibility_by_sex_all': True,
#  'eligibility_by_sex_female': True,
#  'eligibility_by_sex_male': True,
#  'eligibility_exclusion_html': 'history of intolerance to ganciclovir or foscarnet, history of therapy involving the combination of foscarnet and ganciclovir, unwillingness to practice appropriate birth control, active drug or alcohol abuse, media opacity, retinal detachment not scheduled for surgical repair',
#  'eligibility_healthy_volunteers': False,
#  'eligibility_inclusion_html': 'Males and females eligible for the CRRT must have been age 18 years or older and have had AIDS and CMV retinitis. They must have had active CMV despite a minimum of 28 days of previous treatment with an anti-CMV drug. Furthermore, they must have had an absolute neutrophil count greater than or equal to 500 cells/µL, platelet count greater than or equal to 20,000 cells/µL, and a serum creatinine < 2.5 mg/dL in order to tolerate the drug regimens.',
#  'eligibility_tags': [],
#  'is_joinable': False,
#  'is_visible': False,
#  'keywords': ['HIV Infections',
#   'Acquired Immunodeficiency Syndrome',
#   'Cytomegalovirus Retinitis',
#   'Immunologic Deficiency Syndromes',
#   'Retinitis',
#   'Ganciclovir',
#   'Foscarnet',
#   'Phosphonoacetic Acid',
#   'Ganciclovir triphosphate',
#   'intravenous foscarnet',
#   'intravenous ganciclovir'],
#  'summary': 'To compare the relative merits of three therapeutic regimens in patients with AIDS and CMV retinitis who have been previously treated but whose retinitis either is nonresponsive or has relapsed. These three therapeutic regimens were (1) foscarnet, (2) high-dose ganciclovir, and (3) combination foscarnet and ganciclovir. To compare two treatment strategies in patients with relapsed or nonresponsive CMV retinitis: (1) continuing the same anti-CMV drug or (2) switching to the alternate drug.',
#  'title_brief': 'Studies of the Ocular Complications of AIDS (SOCA)--Cytomegalovirus Retinitis Retreatment Trial (CRRT)',
#  'title_official': 'Cytomegalovirus Retinitis Retreatment Trial'}

# %% [markdown]
# #### Exercise 2a
# If you'd like to extend excercise 2, it would be useful to use Spacy/NLTK or something else to break the free text sections from excercise 2 into individual sentences and store them as elements in a list.

# %%
import spacy

nlp = spacy.load('en_core_web_sm')
for trial in analytic_data.keys():
    for element in ['description_html','eligibility_exclusion_html','eligibility_inclusion_html','summary']: 
        new_index = 'parsed_' + element
        doc = nlp(analytic_data[trial][element])
        # Note that if we were keeping this data structure in memory, it would probably be best to keep the 
        # doc object in our data structure, rather than the parsed sentences.
        # Something like: analytic_data[trial][new_index] = doc.sents
        analytic_data[trial][new_index] = [sent.text for sent in doc.sents]

# %%
analytic_data['NCT00000409']
# Out:
# {'conditions': [{'clusters': ['Other'],
#    'name': 'Spondylolisthesis',
#    'slug': 'spondylolisthesis'},
#   {'clusters': ['Other'],
#    'name': 'Spinal Stenosis',
#    'slug': 'spinal-stenosis'},
#   {'clusters': ['Other'], 'name': 'Low Back Pain', 'slug': 'low-back-pain'}],
#  'description_html': 'Low back pain is considered one of the most widely experienced health problems in the U.S. and the world. It is the second most frequent condition, after the common cold, for which patients see a physician or lose days from work. Estimated costs to those who are severely disabled from low back pain range from $30-70 billion annually. Rates of spinal surgery in the U.S. have increased sharply over time, and researchers have documented 15-fold geographic variation in rates of these surgeries. In many cases, where one lives and who one sees for the condition appear to determine the rates of surgery. Despite these trends, there is little evidence proving the effectiveness of these therapies over nonsurgical management.This study will use the National Spine Network to conduct a multicenter, randomized, controlled trial for the three most common diagnostic groups for which spine surgery is performed: lumbar intervertebral disc herniation (IDH), spinal stenosis (SpS), and spinal stenosis secondary to degenerative spondylolisthesis (DS). This arm of the trial will deal with patients from the third diagnostic group. The study will compare the most commonly used standard surgical treatments to the most commonly used standard nonsurgical treatments. We will conduct the study at 12 sites throughout the United States.The primary endpoint of the study will be changes in health-related quality of life as measured by the SF-36 health status questionnaire. Secondary endpoints will include patient satisfaction with treatment, utility for current health in order to estimate quality-adjusted life years (QALYS) as the measure for cost-effectiveness, resource use, and cost.We will follow patients at 6 weeks and 3, 6, 12, and 24 months to determine their health status, function, satisfaction, and health care use. We anticipate that we will enroll and randomly allocate a total of 300 study participants in this arm of the trial. We will track an additional observational cohort to assess health and resource outcomes. Enrollment in the Observational cohort has been completed as of February 2003.We will integrate data from the trial and observational cohorts to formally estimate the cost-effectiveness of surgical versus nonsurgical interventions for IDH, SpS, and DS. The results of this trial will provide, for the first time, scientific evidence as to the relative effectiveness of surgical versus nonsurgical treatment for these three most commonly diagnosed lumbar spine conditions.',
#  'eligibility_by_age_open_to_18_and_over': True,
#  'eligibility_by_sex_all': True,
#  'eligibility_by_sex_female': True,
#  'eligibility_by_sex_male': True,
#  'eligibility_exclusion_html': 'Previous lumbar spine surgery. Not a surgical candidate for any of these reasons: Overall health that makes spinalsurgery too life-threatening to be an appropriate alternative, patient has improveddramatically with conservative care, or the patient is unable (for any reason) toundergo surgery within 6 months. Possible pregnancy. Active malignancy: Patients with a history of any invasive malignancy (exceptnonmelanoma skin cancer) are ineligible unless they have been treated with curativeintent AND have not had any clinical signs or symptoms of the malignancy for at least5 years. Current fracture, infection, and/or deformity (greater than 15 degrees of lumbarscoliosis, using Cobb measure technique) of the spine. Age less than 18 years. Cauda equina syndrome or progressive neurologic deficit (usually requiring urgentsurgery). Unavailability for followup (planning to move, no telephone, etc.) or inability tocomplete data surveys. Symptoms less than 12 weeks. Patient currently enrolled in any experimental "spine related" study.',
#  'eligibility_healthy_volunteers': False,
#  'eligibility_inclusion_html': 'Duration of Symptoms: 12 or more weeks. Treatments Tried: Nonsteroidal. anti-inflammatory medical therapy and physicaltherapy. Surgical Screening: Pain in low back, buttocks, or lower extremity that becomes worsewith lumbar extension. Must be confirmed by evidence of central or central-lateralcompression of the cauda equina by a degenerative lesion of the facet joint, disc, orligamentum flavum on MRI, computed tomography scans, or myelograms. Tests: MRI to confirm diagnosis and level(s).',
#  'eligibility_tags': [],
#  'has_multiple_labels': False,
#  'is_joinable': False,
#  'is_other': True,
#  'is_visible': False,
#  'keywords': ['Spondylolisthesis',
#   'Spinal Stenosis',
#   'Low Back Pain',
#   'Intervertebral disc herniation (IDH)',
#   'Degenerative spondylolisthesis (DS)',
#   'Spinal stenosis (SpS)',
#   'Low back pain (LBP)',
#   'Leg pain',
#   'Surgical therapy',
#   'Randomized study',
#   'Multicenter',
#   'MRI',
#   'Nonsurgical therapy',
#   'Back Pain',
#   'Constriction, Pathologic',
#   'Decompressive laminectomy',
#   'Non-surgical treatments',
#   'Fusion--Instrumented',
#   'Fusion-Non-instrumented',
#   'Surgery'],
#  'labels': {'OTHER'},
#  'parsed_description_html': ['Low back pain is considered one of the most widely experienced health problems in the U.S. and the world.',
#   'It is the second most frequent condition, after the common cold, for which patients see a physician or lose days from work.',
#   'Estimated costs to those who are severely disabled from low back pain range from $30-70 billion annually.',
#   'Rates of spinal surgery in the U.S. have increased sharply over time, and researchers have documented 15-fold geographic variation in rates of these surgeries.',
#   'In many cases, where one lives and who one sees for the condition appear to determine the rates of surgery.',
#   'Despite these trends, there is little evidence proving the effectiveness of these therapies over nonsurgical management.',
#   'This study will use the National Spine Network to conduct a multicenter, randomized, controlled trial for the three most common diagnostic groups for which spine surgery is performed: lumbar intervertebral disc herniation (IDH), spinal stenosis (SpS), and spinal stenosis secondary to degenerative spondylolisthesis (DS).',
#   'This arm of the trial will deal with patients from the third diagnostic group.',
#   'The study will compare the most commonly used standard surgical treatments to the most commonly used standard nonsurgical treatments.',
#   'We will conduct the study at 12 sites throughout the United States.',
#   'The primary endpoint of the study will be changes in health-related quality of life as measured by the SF-36 health status questionnaire.',
#   'Secondary endpoints will include patient satisfaction with treatment, utility for current health in order to estimate quality-adjusted life years (QALYS) as the measure for cost-effectiveness, resource use, and cost.',
#   'We will follow patients at 6 weeks and 3, 6, 12, and 24 months to determine their health status, function, satisfaction, and health care use.',
#   'We anticipate that we will enroll and randomly allocate a total of 300 study participants in this arm of the trial.',
#   'We will track an additional observational cohort to assess health and resource outcomes.',
#   'Enrollment in the Observational cohort has been completed as of February 2003.We will integrate data from the trial and observational cohorts to formally estimate the cost-effectiveness of surgical versus nonsurgical interventions for IDH, SpS, and DS.',
#   'The results of this trial will provide, for the first time, scientific evidence as to the relative effectiveness of surgical versus nonsurgical treatment for these three most commonly diagnosed lumbar spine conditions.'],
#  'parsed_eligibility_exclusion_html': ['Previous lumbar spine surgery.',
#   'Not a surgical candidate for any of these reasons: Overall health that makes spinalsurgery too life-threatening to be an appropriate alternative, patient has improveddramatically with conservative care, or the patient is unable (for any reason) toundergo surgery within 6 months.',
#   'Possible pregnancy.',
#   'Active malignancy: Patients with a history of any invasive malignancy (exceptnonmelanoma skin cancer) are ineligible unless they have been treated with curativeintent AND have not had any clinical signs or symptoms of the malignancy for at least5 years.',
#   'Current fracture, infection, and/or deformity (greater than 15 degrees of lumbarscoliosis, using Cobb measure technique) of the spine.',
#   'Age less than 18 years.',
#   'Cauda equina syndrome or progressive neurologic deficit (usually requiring urgentsurgery).',
#   'Unavailability for followup (planning to move, no telephone, etc.) or inability tocomplete data surveys.',
#   'Symptoms less than 12 weeks.',
#   'Patient currently enrolled in any experimental "spine related" study.'],
#  'parsed_eligibility_inclusion_html': ['Duration of Symptoms: 12 or more weeks.',
#   'Treatments Tried: Nonsteroidal. anti-inflammatory medical therapy and physicaltherapy.',
#   'Surgical Screening:',
#   'Pain in low back, buttocks, or lower extremity that becomes worsewith lumbar extension.',
#   'Must be confirmed by evidence of central or central-lateralcompression of the cauda equina by a degenerative lesion of the facet joint, disc, orligamentum flavum on MRI, computed tomography scans, or myelograms.',
#   'Tests: MRI to confirm diagnosis and level(s).'],
#  'parsed_summary': ['This study tests the effectiveness of different treatments for the three most commonly diagnosed conditions of the lower backbone (lumbar spine).',
#   'The purpose is to learn which of two commonly prescribed treatments (surgery and nonsurgical therapy) works better for specific types of low back pain.',
#   'In this part of the study, we will treat patients with spinal stenosis (a narrowing of spaces in the backbone that results in pressure on the spinal cord and/or nerve roots) caused by degenerative spondylolisthesis (a condition in which one vertebra, or spinal bone, slips forward on another) with either surgery or nonsurgical methods.',
#   'This study does not cover the cost of treatment.'],
#  'summary': 'This study tests the effectiveness of different treatments for the three most commonly diagnosed conditions of the lower backbone (lumbar spine). The purpose is to learn which of two commonly prescribed treatments (surgery and nonsurgical therapy) works better for specific types of low back pain. In this part of the study, we will treat patients with spinal stenosis (a narrowing of spaces in the backbone that results in pressure on the spinal cord and/or nerve roots) caused by degenerative spondylolisthesis (a condition in which one vertebra, or spinal bone, slips forward on another) with either surgery or nonsurgical methods. This study does not cover the cost of treatment.',
#  'title_brief': 'Spine Patient Outcomes Research Trial (SPORT): Degenerative Spondylolisthesis With Spinal Stenosis',
#  'title_official': 'Spine Patient Outcomes Research Trial (SPORT): A Multicenter Randomized Trial for Degenerative Spondylolisthesis (DS) With Spinal Stenosis (SpS) at L4/L5 Level.',
#  'was_other_removed': False}

# %% [markdown]
# #### Exercise 3
# Our goal for our modeling project is to categorize each of the trials into a unique category.  The language of clinicaltrials.ucsf.edu defines "clusters" as the primary category, and "conditions" as the sub-category.  Each trial can be classified as relating to multiple "conditions", and each condition can belong to multiple "clusters." This complicates our modeling task appreciably. To simplify our project, we will assume that all "conditions" are adequately assigned (not a bad assumption, there are very few conditions = "other") and we will assume that any clincical trial that has at least 1 "cluster" not equal to "Other" can be categorized into that non-other cluster.  In other words, we are only interested in classifying trials that cannot be otherwise categorized.
#
# For exercise 3, please create a field in our data structure that indicates whether a specific trial has ONLY "other" clusters (even if there are more than 1).
#
# Let's take a look at the conditions field for trial NCT000004009.  All of the conditions fall under the "other" cluster.

# %%
jdata['NCT00000409']['conditions']
# Out:
# [{'clusters': ['Other'],
#   'name': 'Spondylolisthesis',
#   'slug': 'spondylolisthesis'},
#  {'clusters': ['Other'], 'name': 'Spinal Stenosis', 'slug': 'spinal-stenosis'},
#  {'clusters': ['Other'], 'name': 'Low Back Pain', 'slug': 'low-back-pain'}]

# %% [raw]
# For trial #NCT00000134, however, it has two associated clusters: 'Infectious Diseases' AND 'Other'.

# %%
jdata['NCT00000134']['conditions']
# Out:
# [{'clusters': ['Infectious Diseases'], 'name': 'HIV/AIDS', 'slug': 'hiv-aids'},
#  {'clusters': ['Other'],
#   'name': 'Cytomegalovirus Retinitis',
#   'slug': 'cytomegalovirus-retinitis'}]

# %% [markdown]
# This will be easier to work with if we move it out of the tree array of dictionaries format. Let's put the 1st 11 trials into words first to see what we are looking at.

# %%
trials = []
out_str = ''
for i,y in enumerate(jdata.keys()):
    if i > 10:
        break
    #trials[y] = set()
    out_str = "Trial #{} is:".format(y)
    for c in jdata[y]['conditions']:
        for cl in c['clusters']:
            out_str += " a(n) {} trial under the {} cluster,".format(c['name'],cl) 
    trials.append(out_str[0:-1] + '.')
    out_str = ''
for i in trials:
    print(i)
# Out:
# Trial #NCT00000126 is: a(n) Neuropathy trial under the Brain and Nerves cluster.
# Trial #NCT00000134 is: a(n) HIV/AIDS trial under the Infectious Diseases cluster, a(n) Cytomegalovirus Retinitis trial under the Other cluster.
# Trial #NCT00000136 is: a(n) HIV/AIDS trial under the Infectious Diseases cluster, a(n) Cytomegalovirus Retinitis trial under the Other cluster.
# Trial #NCT00000139 is: a(n) Keratitis, Herpetic trial under the Other cluster, a(n) Ocular Herpes Simplex trial under the Other cluster, a(n) Herpes Simplex trial under the Other cluster.
# Trial #NCT00000142 is: a(n) HIV/AIDS trial under the Infectious Diseases cluster, a(n) CMV Cytomegalovirus Retinitis trial under the Other cluster.
# Trial #NCT00000143 is: a(n) Cytomegalovirus Retinitis trial under the Other cluster, a(n) HIV/AIDS trial under the Infectious Diseases cluster.
# Trial #NCT00000168 is: a(n) HIV/AIDS trial under the Infectious Diseases cluster, a(n) Cytomegalovirus Retinitis trial under the Other cluster.
# Trial #NCT00000173 is: a(n) Alzheimer's Disease trial under the Mental Health cluster, a(n) Alzheimer's Disease trial under the Brain and Nerves cluster, a(n) Mild Cognitive Impairment trial under the Mental Health cluster.
# Trial #NCT00000409 is: a(n) Spondylolisthesis trial under the Other cluster, a(n) Spinal Stenosis trial under the Other cluster, a(n) Low Back Pain trial under the Other cluster.
# Trial #NCT00000410 is: a(n) Herniated Disc trial under the Other cluster, a(n) Low Back Pain trial under the Other cluster.
# Trial #NCT00000411 is: a(n) Spinal Stenosis trial under the Other cluster, a(n) Low Back Pain trial under the Other cluster.

# %% [markdown]
# So 126 is pretty straight forward, it's only assigned to a single cluster: "Brain and Nerves"
#
# 134 & 136 are both a little more difficult. They are HIV/AIDS trials which are assigned to the "Infectious Diseases" cluster, but they are also labeled as cytomegalovirus retinitis trials which has been categorized as "other"
#
# For our purposes, we are going to REMOVE any "other" clusters from consideration if additional clusters are defined. This would mean, for our purposes, 134 & 136 will both be assigned, unambiguously, to the "Infectious Diseases" cluster.
#
# What about trials like 168? Here, it's categorized as both Alzheimer's and Mild Cognitive impairment under the "mental health cluster", and Alzheimer's under the "brain and nerves" cluster. This is a more challenging scenario.  For our purposes, we will retain both unique clusters (mental health/brain & nerves) as shared labels. The trial data will be duplicated and assigned to each cluster. This may have downstream consequences, but let's set things up this way for now.
#
# We'll start by parsing just the unique clusters assigned to each trial

# %%
for i,k in enumerate(analytic_data.keys()):
    #if not x[y]['is_visible'] or not x[y]['is_joinable']:
    #    continue
    
    analytic_data[k]['labels'] = set()

    for c in analytic_data[k]['conditions']:
        for cl in c['clusters']:
            analytic_data[k]['labels'].add(cl.upper())
    #print("TRIAL# {} => {}".format(k, analytic_data[k]['labels']))
#print(trials)
#print("__________________")
#print(len(trials))

# %% [markdown]
# And now, we'll remove any "other" clusters from the label set if there is a suitable default.

# %%
for k in analytic_data.keys():
    analytic_data[k]['has_multiple_labels'] = False
    analytic_data[k]['was_other_removed'] = False
    analytic_data[k]['is_other'] = False
    
    if 'OTHER' in analytic_data[k]['labels']:
        if len(analytic_data[k]['labels']) > 1:    
            # Could be assigned to something besides other
            analytic_data[k]['labels'].remove('OTHER')
            analytic_data[k]['was_other_removed'] = True
        else:
            analytic_data[k]['is_other'] = True
    if len(analytic_data[k]['labels']) > 1: 
        # Multiple assignments remain
        analytic_data[k]['has_multiple_labels'] = True
    
#    if analytic_data[k]['is_other']:
#        print("{}: => {}".format(k, ','.join(list(analytic_data[k]['labels']))))
#    if analytic_data[k]['is_other']:
#        print("{}: => {}".format(k, ','.join(list(analytic_data[k]['labels']))))

# %%
["{}: => {}".format(k, ','.join(list(analytic_data[k]['labels']))) for k in analytic_data.keys() if analytic_data[k]['has_multiple_labels']]
# Out:
# ['NCT00000173: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT00000657: => INFECTIOUS DISEASES,BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT00000658: => CANCER,INFECTIOUS DISEASES',
#  'NCT00000660: => CANCER,INFECTIOUS DISEASES',
#  'NCT00000703: => CANCER,INFECTIOUS DISEASES',
#  'NCT00000751: => INFECTIOUS DISEASES,REPRODUCTIVE HEALTH',
#  'NCT00000793: => BRAIN AND NERVES,INFECTIOUS DISEASES',
#  'NCT00000801: => CANCER,INFECTIOUS DISEASES',
#  'NCT00000807: => CANCER,INFECTIOUS DISEASES',
#  'NCT00000808: => INFECTIOUS DISEASES,REPRODUCTIVE HEALTH',
#  'NCT00000862: => INFECTIOUS DISEASES,REPRODUCTIVE HEALTH',
#  'NCT00000867: => INFECTIOUS DISEASES,BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT00000869: => INFECTIOUS DISEASES,REPRODUCTIVE HEALTH',
#  'NCT00000917: => INFECTIOUS DISEASES,REPRODUCTIVE HEALTH',
#  'NCT00000944: => INFECTIOUS DISEASES,REPRODUCTIVE HEALTH',
#  'NCT00000954: => CANCER,INFECTIOUS DISEASES',
#  'NCT00000960: => INFECTIOUS DISEASES,REPRODUCTIVE HEALTH',
#  'NCT00000994: => CANCER,INFECTIOUS DISEASES',
#  'NCT00000996: => CANCER,INFECTIOUS DISEASES',
#  'NCT00001041: => INFECTIOUS DISEASES,REPRODUCTIVE HEALTH',
#  'NCT00001059: => CANCER,INFECTIOUS DISEASES',
#  'NCT00001120: => CANCER,INFECTIOUS DISEASES',
#  'NCT00001135: => INFECTIOUS DISEASES,REPRODUCTIVE HEALTH',
#  'NCT00002126: => BLOOD, HEART, AND CIRCULATION,INFECTIOUS DISEASES',
#  'NCT00002138: => CANCER,INFECTIOUS DISEASES',
#  'NCT00002163: => INFECTIOUS DISEASES,BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT00002167: => CANCER,INFECTIOUS DISEASES',
#  'NCT00002252: => DIGESTIVE SYSTEM,INFECTIOUS DISEASES',
#  'NCT00002253: => DIGESTIVE SYSTEM,INFECTIOUS DISEASES',
#  'NCT00002262: => CANCER,INFECTIOUS DISEASES',
#  'NCT00002318: => CANCER,INFECTIOUS DISEASES',
#  'NCT00002319: => CANCER,INFECTIOUS DISEASES',
#  'NCT00002408: => DIGESTIVE SYSTEM,INFECTIOUS DISEASES',
#  'NCT00002445: => CANCER,INFECTIOUS DISEASES',
#  'NCT00002643: => CANCER,BLOOD, HEART, AND CIRCULATION',
#  'NCT00002805: => CANCER,BLOOD, HEART, AND CIRCULATION',
#  'NCT00002875: => CANCER,BRAIN AND NERVES',
#  'NCT00002944: => CANCER,BRAIN AND NERVES',
#  'NCT00003057: => DIGESTIVE SYSTEM,CANCER',
#  'NCT00003072: => CANCER,BRAIN AND NERVES',
#  'NCT00003141: => CANCER,BRAIN AND NERVES',
#  'NCT00003162: => CANCER,BRAIN AND NERVES',
#  'NCT00003203: => CANCER,BRAIN AND NERVES',
#  'NCT00003241: => CANCER,BRAIN AND NERVES',
#  'NCT00003323: => CANCER,REPRODUCTIVE HEALTH',
#  'NCT00003575: => CANCER,INFECTIOUS DISEASES',
#  'NCT00003593: => CANCER,BLOOD, HEART, AND CIRCULATION',
#  'NCT00003675: => CANCER,BLOOD, HEART, AND CIRCULATION',
#  'NCT00003739: => CANCER,BLOOD, HEART, AND CIRCULATION',
#  'NCT00003790: => CANCER,BLOOD, HEART, AND CIRCULATION',
#  'NCT00003793: => CANCER,BLOOD, HEART, AND CIRCULATION',
#  'NCT00004917: => CANCER,BLOOD, HEART, AND CIRCULATION',
#  'NCT00004984: => ENDOCRINE SYSTEM,METABOLIC PROBLEMS',
#  'NCT00006024: => CANCER,BRAIN AND NERVES',
#  'NCT00006222: => CANCER,INFECTIOUS DISEASES',
#  'NCT00006247: => CANCER,BRAIN AND NERVES',
#  'NCT00006358: => CANCER,BRAIN AND NERVES',
#  'NCT00006412: => INFECTIOUS DISEASES,METABOLIC PROBLEMS',
#  'NCT00006747: => CANCER,ORGAN AND TISSUE TRANSPLANT',
#  'NCT00006994: => CANCER,BRAIN AND NERVES',
#  'NCT00007007: => CANCER,BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT00009854: => CANCER,BRAIN AND NERVES',
#  'NCT00010049: => CANCER,TUMORS',
#  'NCT00012974: => MENTAL HEALTH,BLOOD, HEART, AND CIRCULATION',
#  'NCT00015691: => INFECTIOUS DISEASES,METABOLIC PROBLEMS',
#  'NCT00015899: => CANCER,BRAIN AND NERVES',
#  'NCT00017719: => INFECTIOUS DISEASES,REPRODUCTIVE HEALTH',
#  'NCT00019422: => CANCER,BRAIN AND NERVES',
#  'NCT00027846: => CANCER,BRAIN AND NERVES,TUMORS',
#  'NCT00036244: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT00039975: => BLOOD, HEART, AND CIRCULATION,INFECTIOUS DISEASES',
#  'NCT00041964: => INFECTIOUS DISEASES,REPRODUCTIVE HEALTH',
#  'NCT00045110: => CANCER,TUMORS,BRAIN AND NERVES',
#  'NCT00045734: => CANCER,TUMORS,BRAIN AND NERVES',
#  'NCT00046709: => CANCER,TUMORS',
#  'NCT00046722: => BRAIN AND NERVES,INFECTIOUS DISEASES',
#  'NCT00047320: => CANCER,BRAIN AND NERVES',
#  'NCT00048958: => CANCER,BLOOD, HEART, AND CIRCULATION',
#  'NCT00048971: => DIGESTIVE SYSTEM,CANCER,BLOOD, HEART, AND CIRCULATION',
#  'NCT00052897: => CANCER,INFECTIOUS DISEASES',
#  'NCT00053053: => CANCER,BLOOD, HEART, AND CIRCULATION',
#  'NCT00053352: => CANCER,TUMORS',
#  'NCT00055653: => CANCER,BLOOD, HEART, AND CIRCULATION',
#  'NCT00056524: => BRAIN AND NERVES,INJURIES,MENTAL HEALTH',
#  'NCT00060801: => BLOOD, HEART, AND CIRCULATION,DIGESTIVE SYSTEM,INJURIES,LUNGS AND BREATHING',
#  'NCT00061828: => DIGESTIVE SYSTEM,FETUS OR NEWBORN DISORDERS',
#  'NCT00064753: => BLOOD, HEART, AND CIRCULATION,KIDNEYS AND URINARY SYSTEM',
#  'NCT00066248: => CANCER,BRAIN AND NERVES,BLOOD, HEART, AND CIRCULATION',
#  'NCT00066430: => CANCER,INFECTIOUS DISEASES',
#  'NCT00069004: => BONES, JOINTS, AND MUSCLES,INFECTIOUS DISEASES,METABOLIC PROBLEMS',
#  'NCT00069368: => ENDOCRINE SYSTEM,KIDNEYS AND URINARY SYSTEM,METABOLIC PROBLEMS',
#  'NCT00069524: => INFECTIOUS DISEASES,METABOLIC PROBLEMS',
#  'NCT00069589: => IMMUNE SYSTEM,SKIN DISORDERS',
#  'NCT00070135: => CANCER,BLOOD, HEART, AND CIRCULATION',
#  'NCT00071461: => BLOOD, HEART, AND CIRCULATION,DIGESTIVE SYSTEM,INJURIES,LUNGS AND BREATHING',
#  'NCT00074386: => DIGESTIVE SYSTEM,ORGAN AND TISSUE TRANSPLANT,KIDNEYS AND URINARY SYSTEM,INFECTIOUS DISEASES',
#  'NCT00076518: => INFECTIOUS DISEASES,METABOLIC PROBLEMS',
#  'NCT00078403: => DIGESTIVE SYSTEM,INFECTIOUS DISEASES',
#  'NCT00078988: => CANCER,BRAIN AND NERVES',
#  'NCT00080236: => DIGESTIVE SYSTEM,ORGAN AND TISSUE TRANSPLANT,CANCER,INFECTIOUS DISEASES',
#  'NCT00082628: => INFECTIOUS DISEASES,METABOLIC PROBLEMS',
#  'NCT00085176: => CANCER,BRAIN AND NERVES',
#  'NCT00085449: => CANCER,BLOOD, HEART, AND CIRCULATION',
#  'NCT00085540: => CANCER,BRAIN AND NERVES',
#  'NCT00086190: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT00087633: => ORGAN AND TISSUE TRANSPLANT,INFECTIOUS DISEASES',
#  'NCT00090987: => CANCER,INFECTIOUS DISEASES',
#  'NCT00091949: => ENDOCRINE SYSTEM,BRAIN AND NERVES,BLOOD, HEART, AND CIRCULATION,METABOLIC PROBLEMS',
#  'NCT00093353: => DIGESTIVE SYSTEM,CANCER',
#  'NCT00096733: => DIGESTIVE SYSTEM,CANCER,ORGAN AND TISSUE TRANSPLANT,INFECTIOUS DISEASES',
#  'NCT00097084: => ENDOCRINE SYSTEM,METABOLIC PROBLEMS',
#  'NCT00097292: => ENDOCRINE SYSTEM,METABOLIC PROBLEMS',
#  'NCT00097773: => INJURIES,BLOOD, HEART, AND CIRCULATION,DIGESTIVE SYSTEM,LUNGS AND BREATHING',
#  'NCT00098761: => CANCER,BRAIN AND NERVES',
#  'NCT00100178: => ENDOCRINE SYSTEM,METABOLIC PROBLEMS',
#  'NCT00100542: => MENTAL HEALTH,INFECTIOUS DISEASES',
#  'NCT00100802: => CANCER,BRAIN AND NERVES',
#  'NCT00104338: => ORGAN AND TISSUE TRANSPLANT,KIDNEYS AND URINARY SYSTEM',
#  'NCT00105183: => INJURIES,BLOOD, HEART, AND CIRCULATION,DIGESTIVE SYSTEM,LUNGS AND BREATHING',
#  'NCT00105235: => DIGESTIVE SYSTEM,ORGAN AND TISSUE TRANSPLANT',
#  'NCT00105352: => ENDOCRINE SYSTEM,METABOLIC PROBLEMS',
#  'NCT00105547: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT00106353: => CANCER,TUMORS',
#  'NCT00106899: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT00108745: => CANCER,TUMORS',
#  'NCT00109681: => BLOOD, HEART, AND CIRCULATION,DIGESTIVE SYSTEM,INJURIES,LUNGS AND BREATHING',
#  'NCT00112073: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT00112736: => CANCER,BRAIN AND NERVES',
#  'NCT00129259: => ENDOCRINE SYSTEM,METABOLIC PROBLEMS',
#  'NCT00129961: => ORGAN AND TISSUE TRANSPLANT,CANCER',
#  'NCT00133679: => BLOOD, HEART, AND CIRCULATION,BONES, JOINTS, AND MUSCLES',
#  'NCT00135694: => DIGESTIVE SYSTEM,ORGAN AND TISSUE TRANSPLANT,INFECTIOUS DISEASES',
#  'NCT00135798: => ORGAN AND TISSUE TRANSPLANT,INFECTIOUS DISEASES',
#  'NCT00139516: => ENDOCRINE SYSTEM,METABOLIC PROBLEMS,BLOOD, HEART, AND CIRCULATION,DRUG DEPENDENCE AND RELATED DISORDERS',
#  'NCT00141037: => ORGAN AND TISSUE TRANSPLANT,KIDNEYS AND URINARY SYSTEM',
#  'NCT00187486: => CANCER,BRAIN AND NERVES',
#  'NCT00187564: => ENDOCRINE SYSTEM,METABOLIC PROBLEMS',
#  'NCT00187785: => ENDOCRINE SYSTEM,BLOOD, HEART, AND CIRCULATION,METABOLIC PROBLEMS',
#  'NCT00212329: => ENDOCRINE SYSTEM,METABOLIC PROBLEMS',
#  'NCT00214474: => ENDOCRINE SYSTEM,METABOLIC PROBLEMS',
#  'NCT00217737: => CANCER,GENETICS AND BIRTH DEFECTS',
#  'NCT00228592: => DIGESTIVE SYSTEM,ORGAN AND TISSUE TRANSPLANT,INFECTIOUS DISEASES',
#  'NCT00238264: => CANCER,BRAIN AND NERVES',
#  'NCT00240994: => ORGAN AND TISSUE TRANSPLANT,IMMUNE SYSTEM,KIDNEYS AND URINARY SYSTEM',
#  'NCT00248625: => DIGESTIVE SYSTEM,BRAIN AND NERVES',
#  'NCT00256750: => ORGAN AND TISSUE TRANSPLANT,KIDNEYS AND URINARY SYSTEM',
#  'NCT00262847: => CANCER,TUMORS',
#  'NCT00268385: => CANCER,BRAIN AND NERVES',
#  'NCT00270634: => ORGAN AND TISSUE TRANSPLANT,KIDNEYS AND URINARY SYSTEM',
#  'NCT00274313: => BLOOD, HEART, AND CIRCULATION,DIGESTIVE SYSTEM,INJURIES,LUNGS AND BREATHING',
#  'NCT00279045: => ENDOCRINE SYSTEM,METABOLIC PROBLEMS',
#  'NCT00279305: => ENDOCRINE SYSTEM,METABOLIC PROBLEMS',
#  'NCT00295945: => CANCER,BRAIN AND NERVES',
#  'NCT00295971: => CANCER,BLOOD, HEART, AND CIRCULATION,BONES, JOINTS, AND MUSCLES',
#  'NCT00295997: => CANCER,BLOOD, HEART, AND CIRCULATION',
#  'NCT00296023: => CANCER,BLOOD, HEART, AND CIRCULATION',
#  'NCT00297453: => DRUG DEPENDENCE AND RELATED DISORDERS,INFECTIOUS DISEASES',
#  'NCT00301834: => CANCER,BLOOD, HEART, AND CIRCULATION',
#  'NCT00301912: => CANCER,BLOOD, HEART, AND CIRCULATION',
#  'NCT00301951: => CANCER,BLOOD, HEART, AND CIRCULATION',
#  'NCT00304018: => CANCER,BLOOD, HEART, AND CIRCULATION',
#  'NCT00305708: => CANCER,BLOOD, HEART, AND CIRCULATION',
#  'NCT00313729: => CANCER,BRAIN AND NERVES',
#  'NCT00319891: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT00320606: => ORGAN AND TISSUE TRANSPLANT,IMMUNE SYSTEM',
#  'NCT00323882: => CANCER,TUMORS',
#  'NCT00326664: => CANCER,TUMORS,BRAIN AND NERVES',
#  'NCT00333554: => ENDOCRINE SYSTEM,METABOLIC PROBLEMS',
#  'NCT00335764: => CANCER,BRAIN AND NERVES',
#  'NCT00338767: => MENTAL HEALTH,INFECTIOUS DISEASES',
#  'NCT00341484: => CANCER,INFECTIOUS DISEASES',
#  'NCT00341614: => ENDOCRINE SYSTEM,BLOOD, HEART, AND CIRCULATION,METABOLIC PROBLEMS',
#  'NCT00369317: => CANCER,BLOOD, HEART, AND CIRCULATION',
#  'NCT00369590: => CANCER,BRAIN AND NERVES',
#  'NCT00378508: => ENDOCRINE SYSTEM,METABOLIC PROBLEMS',
#  'NCT00381797: => CANCER,TUMORS',
#  'NCT00382109: => ORGAN AND TISSUE TRANSPLANT,CANCER',
#  'NCT00385697: => ENDOCRINE SYSTEM,METABOLIC PROBLEMS',
#  'NCT00387894: => CANCER,BRAIN AND NERVES',
#  'NCT00387920: => CANCER,TUMORS',
#  'NCT00391443: => INJURIES,BLOOD, HEART, AND CIRCULATION,DIGESTIVE SYSTEM,LUNGS AND BREATHING',
#  'NCT00392834: => CANCER,INFECTIOUS DISEASES',
#  'NCT00407381: => ENDOCRINE SYSTEM,EYES AND VISION,METABOLIC PROBLEMS',
#  'NCT00412360: => CANCER,BLOOD, HEART, AND CIRCULATION',
#  'NCT00418899: => CANCER,BRAIN AND NERVES',
#  'NCT00419562: => ENDOCRINE SYSTEM,METABOLIC PROBLEMS',
#  'NCT00434811: => ENDOCRINE SYSTEM,METABOLIC PROBLEMS',
#  'NCT00434850: => ENDOCRINE SYSTEM,METABOLIC PROBLEMS',
#  'NCT00436748: => KIDNEYS AND URINARY SYSTEM,BLOOD, HEART, AND CIRCULATION',
#  'NCT00437060: => CANCER,BRAIN AND NERVES',
#  'NCT00450450: => CANCER,BLOOD, HEART, AND CIRCULATION',
#  'NCT00451828: => BLOOD, HEART, AND CIRCULATION,METABOLIC PROBLEMS',
#  'NCT00453388: => CANCER,BLOOD, HEART, AND CIRCULATION',
#  'NCT00458887: => CANCER,EAR, NOSE, AND THROAT',
#  'NCT00459381: => CANCER,BRAIN AND NERVES',
#  'NCT00467051: => CANCER,TUMORS',
#  'NCT00467220: => BLOOD, HEART, AND CIRCULATION,METABOLIC PROBLEMS',
#  'NCT00468117: => ENDOCRINE SYSTEM,ORGAN AND TISSUE TRANSPLANT,METABOLIC PROBLEMS',
#  'NCT00471614: => INFECTIOUS DISEASES,METABOLIC PROBLEMS',
#  'NCT00472095: => ENDOCRINE SYSTEM,METABOLIC PROBLEMS',
#  'NCT00498602: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT00499720: => INFECTIOUS DISEASES,INJURIES,BLOOD, HEART, AND CIRCULATION,DIGESTIVE SYSTEM,LUNGS AND BREATHING',
#  'NCT00501709: => ENDOCRINE SYSTEM,METABOLIC PROBLEMS',
#  'NCT00502788: => BLOOD, HEART, AND CIRCULATION,INFECTIOUS DISEASES',
#  'NCT00503308: => INFECTIOUS DISEASES,REPRODUCTIVE HEALTH',
#  'NCT00505375: => ENDOCRINE SYSTEM,METABOLIC PROBLEMS',
#  'NCT00507689: => ORGAN AND TISSUE TRANSPLANT,INFECTIOUS DISEASES',
#  'NCT00508937: => BLOOD, HEART, AND CIRCULATION,ENDOCRINE SYSTEM,METABOLIC PROBLEMS',
#  'NCT00513175: => CANCER,BLOOD, HEART, AND CIRCULATION',
#  'NCT00513526: => CANCER,INFECTIOUS DISEASES',
#  'NCT00515099: => ENDOCRINE SYSTEM,METABOLIC PROBLEMS',
#  'NCT00516152: => CANCER,BLOOD, HEART, AND CIRCULATION',
#  'NCT00517933: => BLOOD, HEART, AND CIRCULATION,DIGESTIVE SYSTEM,INJURIES,LUNGS AND BREATHING',
#  'NCT00529399: => ENDOCRINE SYSTEM,METABOLIC PROBLEMS',
#  'NCT00535886: => ENDOCRINE SYSTEM,BLOOD, HEART, AND CIRCULATION,METABOLIC PROBLEMS',
#  'NCT00545974: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT00548782: => ENDOCRINE SYSTEM,METABOLIC PROBLEMS',
#  'NCT00550589: => CANCER,INFECTIOUS DISEASES',
#  'NCT00557180: => LUNGS AND BREATHING,METABOLIC PROBLEMS',
#  'NCT00565851: => CANCER,TUMORS',
#  'NCT00566397: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT00568776: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT00571272: => MULTISYSTEM DISORDERS,DIGESTIVE SYSTEM,GENETICS AND BIRTH DEFECTS',
#  'NCT00574132: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT00575055: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT00584480: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT00584701: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT00596232: => BLOOD, HEART, AND CIRCULATION,DIGESTIVE SYSTEM,INJURIES,LUNGS AND BREATHING',
#  'NCT00597909: => DIGESTIVE SYSTEM,BRAIN AND NERVES',
#  'NCT00606476: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT00608023: => INFECTIOUS DISEASES,METABOLIC PROBLEMS',
#  'NCT00611182: => BLOOD, HEART, AND CIRCULATION,DIGESTIVE SYSTEM,INJURIES,LUNGS AND BREATHING',
#  'NCT00619112: => CANCER,BRAIN AND NERVES',
#  'NCT00631475: => BLOOD, HEART, AND CIRCULATION,DIGESTIVE SYSTEM,INJURIES,LUNGS AND BREATHING',
#  'NCT00636064: => BRAIN AND NERVES,BLOOD, HEART, AND CIRCULATION',
#  'NCT00644761: => ORGAN AND TISSUE TRANSPLANT,INFECTIOUS DISEASES',
#  'NCT00645788: => BLOOD, HEART, AND CIRCULATION,DIGESTIVE SYSTEM,INJURIES,LUNGS AND BREATHING',
#  'NCT00650091: => BLOOD, HEART, AND CIRCULATION,DIGESTIVE SYSTEM,INJURIES,LUNGS AND BREATHING',
#  'NCT00650923: => CANCER,BRAIN AND NERVES',
#  'NCT00676169: => BLOOD, HEART, AND CIRCULATION,DIGESTIVE SYSTEM,INJURIES,LUNGS AND BREATHING',
#  'NCT00679354: => CANCER,BRAIN AND NERVES',
#  'NCT00683020: => ENDOCRINE SYSTEM,METABOLIC PROBLEMS',
#  'NCT00695422: => CANCER,INFECTIOUS DISEASES',
#  'NCT00703417: => ENDOCRINE SYSTEM,METABOLIC PROBLEMS,BONES, JOINTS, AND MUSCLES',
#  'NCT00708019: => CANCER,BRAIN AND NERVES',
#  'NCT00714129: => DIGESTIVE SYSTEM,ENDOCRINE SYSTEM,METABOLIC PROBLEMS',
#  'NCT00714441: => ENDOCRINE SYSTEM,METABOLIC PROBLEMS',
#  'NCT00716976: => CANCER,BRAIN AND NERVES,EAR, NOSE, AND THROAT',
#  'NCT00727051: => ORGAN AND TISSUE TRANSPLANT,BLOOD, HEART, AND CIRCULATION',
#  'NCT00732108: => BRAIN AND NERVES,BLOOD, HEART, AND CIRCULATION',
#  'NCT00736749: => CANCER,BRAIN AND NERVES',
#  'NCT00755313: => CANCER,MENTAL HEALTH,BRAIN AND NERVES',
#  'NCT00758771: => BLOOD, HEART, AND CIRCULATION,DIGESTIVE SYSTEM,INJURIES,LUNGS AND BREATHING',
#  'NCT00768300: => BLOOD, HEART, AND CIRCULATION,DIGESTIVE SYSTEM,INJURIES,LUNGS AND BREATHING',
#  'NCT00768729: => ORGAN AND TISSUE TRANSPLANT,IMMUNE SYSTEM,KIDNEYS AND URINARY SYSTEM',
#  'NCT00770926: => ENDOCRINE SYSTEM,METABOLIC PROBLEMS',
#  'NCT00772200: => CANCER,MENTAL HEALTH,BRAIN AND NERVES',
#  'NCT00786799: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT00800982: => METABOLIC PROBLEMS,SKIN DISORDERS',
#  'NCT00806572: => ENDOCRINE SYSTEM,METABOLIC PROBLEMS',
#  'NCT00807768: => CANCER,METABOLIC PROBLEMS,BRAIN AND NERVES',
#  'NCT00826241: => CANCER,BRAIN AND NERVES,TUMORS',
#  'NCT00829374: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT00833677: => ENDOCRINE SYSTEM,METABOLIC PROBLEMS',
#  'NCT00843713: => BLOOD, HEART, AND CIRCULATION,INFECTIOUS DISEASES',
#  'NCT00844519: => BLOOD, HEART, AND CIRCULATION,INFECTIOUS DISEASES',
#  'NCT00844714: => EYES AND VISION,IMMUNE SYSTEM',
#  'NCT00845013: => BLOOD, HEART, AND CIRCULATION,EYES AND VISION,INFECTIOUS DISEASES',
#  'NCT00852267: => BLOOD, HEART, AND CIRCULATION,METABOLIC PROBLEMS',
#  'NCT00870857: => LUNGS AND BREATHING,INFECTIOUS DISEASES',
#  'NCT00872898: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT00878059: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT00878306: => DRUG DEPENDENCE AND RELATED DISORDERS,INFECTIOUS DISEASES',
#  'NCT00879229: => BLOOD, HEART, AND CIRCULATION,DIGESTIVE SYSTEM,INJURIES,LUNGS AND BREATHING',
#  'NCT00881452: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT00895622: => CANCER,TUMORS',
#  'NCT00897442: => CANCER,TUMORS',
#  'NCT00898079: => CANCER,TUMORS',
#  'NCT00898365: => CANCER,KIDNEYS AND URINARY SYSTEM,TUMORS',
#  'NCT00899223: => CANCER,BLOOD, HEART, AND CIRCULATION',
#  'NCT00903331: => BLOOD, HEART, AND CIRCULATION,DIGESTIVE SYSTEM,INJURIES,LUNGS AND BREATHING',
#  'NCT00912691: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT00919269: => CANCER,TUMORS',
#  'NCT00919750: => CANCER,TUMORS,BRAIN AND NERVES',
#  'NCT00919997: => CANCER,INFECTIOUS DISEASES',
#  'NCT00931528: => CANCER,REPRODUCTIVE HEALTH',
#  'NCT00937352: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT00938860: => ORGAN AND TISSUE TRANSPLANT,INFECTIOUS DISEASES',
#  'NCT00947427: => ENDOCRINE SYSTEM,METABOLIC PROBLEMS',
#  'NCT00951496: => CANCER,TUMORS',
#  'NCT00957242: => BLOOD, HEART, AND CIRCULATION,DIGESTIVE SYSTEM,INJURIES,LUNGS AND BREATHING',
#  'NCT00960531: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT00965458: => ENDOCRINE SYSTEM,METABOLIC PROBLEMS',
#  'NCT00970099: => ENDOCRINE SYSTEM,METABOLIC PROBLEMS',
#  'NCT00974623: => CANCER,TUMORS,BONES, JOINTS, AND MUSCLES',
#  'NCT00975000: => ORGAN AND TISSUE TRANSPLANT,KIDNEYS AND URINARY SYSTEM',
#  'NCT00980343: => CANCER,BRAIN AND NERVES',
#  'NCT00986648: => DIGESTIVE SYSTEM,BRAIN AND NERVES',
#  'NCT00988117: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT00990379: => BRAIN AND NERVES,INFECTIOUS DISEASES',
#  'NCT00990730: => IMMUNE SYSTEM,BLOOD, HEART, AND CIRCULATION',
#  'NCT00995878: => TUMORS,REPRODUCTIVE HEALTH',
#  'NCT01000753: => CANCER,BLOOD, HEART, AND CIRCULATION',
#  'NCT01017523: => ENDOCRINE SYSTEM,METABOLIC PROBLEMS',
#  'NCT01027325: => BLOOD, HEART, AND CIRCULATION,METABOLIC PROBLEMS',
#  'NCT01030861: => ENDOCRINE SYSTEM,IMMUNE SYSTEM,METABOLIC PROBLEMS',
#  'NCT01036009: => CANCER,BLOOD, HEART, AND CIRCULATION',
#  'NCT01039116: => ENDOCRINE SYSTEM,METABOLIC PROBLEMS',
#  'NCT01039792: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT01040676: => ENDOCRINE SYSTEM,METABOLIC PROBLEMS',
#  'NCT01040806: => ENDOCRINE SYSTEM,METABOLIC PROBLEMS',
#  'NCT01042379: => CANCER,TUMORS',
#  'NCT01056965: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT01057121: => CANCER,INFECTIOUS DISEASES',
#  'NCT01071707: => BLOOD, HEART, AND CIRCULATION,DIGESTIVE SYSTEM,INJURIES,LUNGS AND BREATHING',
#  'NCT01078636: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT01082965: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT01089101: => CANCER,TUMORS',
#  'NCT01092663: => ENDOCRINE SYSTEM,METABOLIC PROBLEMS',
#  'NCT01096368: => CANCER,TUMORS',
#  'NCT01106157: => ENDOCRINE SYSTEM,METABOLIC PROBLEMS',
#  'NCT01141712: => CANCER,INFECTIOUS DISEASES',
#  'NCT01148550: => GENETICS AND BIRTH DEFECTS,METABOLIC PROBLEMS,DIGESTIVE SYSTEM,LUNGS AND BREATHING',
#  'NCT01150591: => BLOOD, HEART, AND CIRCULATION,DIGESTIVE SYSTEM,INJURIES,LUNGS AND BREATHING',
#  'NCT01164163: => CANCER,BLOOD, HEART, AND CIRCULATION',
#  'NCT01164722: => INFECTIOUS DISEASES,CANCER,TUMORS',
#  'NCT01167712: => CANCER,TUMORS',
#  'NCT01169337: => CANCER,IMMUNE SYSTEM',
#  'NCT01175499: => CANCER,TUMORS',
#  'NCT01180634: => BLOOD, HEART, AND CIRCULATION,DIGESTIVE SYSTEM,INJURIES,LUNGS AND BREATHING',
#  'NCT01186913: => GENETICS AND BIRTH DEFECTS,IMMUNE SYSTEM,BLOOD, HEART, AND CIRCULATION,METABOLIC PROBLEMS',
#  'NCT01189240: => CANCER,BRAIN AND NERVES',
#  'NCT01190930: => CANCER,GENETICS AND BIRTH DEFECTS',
#  'NCT01193842: => CANCER,INFECTIOUS DISEASES',
#  'NCT01200017: => IMMUNE SYSTEM,BONES, JOINTS, AND MUSCLES,BLOOD, HEART, AND CIRCULATION,CANCER',
#  'NCT01209325: => CANCER,INFECTIOUS DISEASES',
#  'NCT01210664: => ENDOCRINE SYSTEM,METABOLIC PROBLEMS',
#  'NCT01214187: => BLOOD, HEART, AND CIRCULATION,DIGESTIVE SYSTEM,INJURIES,LUNGS AND BREATHING',
#  'NCT01220336: => BLOOD, HEART, AND CIRCULATION,ENDOCRINE SYSTEM,METABOLIC PROBLEMS',
#  'NCT01223248: => BRAIN AND NERVES,CANCER,BLOOD, HEART, AND CIRCULATION,BONES, JOINTS, AND MUSCLES',
#  'NCT01227668: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT01229709: => BRAIN AND NERVES,MENTAL HEALTH,EAR, NOSE, AND THROAT',
#  'NCT01229943: => CANCER,TUMORS',
#  'NCT01231919: => CANCER,BLOOD, HEART, AND CIRCULATION',
#  'NCT01231971: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT01236560: => CANCER,TUMORS',
#  'NCT01262560: => CANCER,BRAIN AND NERVES',
#  'NCT01272635: => RESPIRATORY DISEASES,LUNGS AND BREATHING',
#  'NCT01273090: => CANCER,BLOOD, HEART, AND CIRCULATION',
#  'NCT01276236: => CANCER,INFECTIOUS DISEASES',
#  'NCT01284387: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT01305200: => CANCER,BLOOD, HEART, AND CIRCULATION',
#  'NCT01307579: => BLOOD, HEART, AND CIRCULATION,CANCER,INFECTIOUS DISEASES',
#  'NCT01316549: => GENETICS AND BIRTH DEFECTS,IMMUNE SYSTEM,BLOOD, HEART, AND CIRCULATION,CANCER',
#  'NCT01333644: => BLOOD, HEART, AND CIRCULATION,INFECTIOUS DISEASES',
#  'NCT01340482: => GENETICS AND BIRTH DEFECTS,METABOLIC PROBLEMS',
#  'NCT01341132: => DIGESTIVE SYSTEM,CANCER',
#  'NCT01343966: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT01346150: => BLOOD, HEART, AND CIRCULATION,GENETICS AND BIRTH DEFECTS,IMMUNE SYSTEM,METABOLIC PROBLEMS',
#  'NCT01346358: => CANCER,TUMORS',
#  'NCT01351545: => GENETICS AND BIRTH DEFECTS,IMMUNE SYSTEM,METABOLIC PROBLEMS,BLOOD, HEART, AND CIRCULATION,CANCER',
#  'NCT01353625: => CANCER,TUMORS',
#  'NCT01368822: => BLOOD, HEART, AND CIRCULATION,METABOLIC PROBLEMS',
#  'NCT01369069: => ENDOCRINE SYSTEM,BRAIN AND NERVES,METABOLIC PROBLEMS',
#  'NCT01369082: => ENDOCRINE SYSTEM,ORGAN AND TISSUE TRANSPLANT,METABOLIC PROBLEMS',
#  'NCT01371214: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT01371305: => BLOOD, HEART, AND CIRCULATION,DIGESTIVE SYSTEM,INJURIES,LUNGS AND BREATHING',
#  'NCT01371656: => INFECTIOUS DISEASES,BLOOD, HEART, AND CIRCULATION,DIGESTIVE SYSTEM,CANCER',
#  'NCT01372592: => INJURIES,BONES, JOINTS, AND MUSCLES',
#  'NCT01404897: => BLOOD, HEART, AND CIRCULATION,METABOLIC PROBLEMS',
#  'NCT01409135: => CANCER,TUMORS',
#  'NCT01410344: => CANCER,INFECTIOUS DISEASES',
#  'NCT01412216: => BLOOD, HEART, AND CIRCULATION,METABOLIC PROBLEMS',
#  'NCT01420627: => IMMUNE SYSTEM,METABOLIC PROBLEMS',
#  'NCT01421212: => DIGESTIVE SYSTEM,ORGAN AND TISSUE TRANSPLANT,INFECTIOUS DISEASES',
#  'NCT01427855: => BLOOD, HEART, AND CIRCULATION,METABOLIC PROBLEMS',
#  'NCT01434290: => CANCER,REPRODUCTIVE HEALTH',
#  'NCT01461681: => BLOOD, HEART, AND CIRCULATION,BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT01462695: => CANCER,TUMORS',
#  'NCT01463046: => CANCER,BLOOD, HEART, AND CIRCULATION',
#  'NCT01467466: => BLOOD, HEART, AND CIRCULATION,KIDNEYS AND URINARY SYSTEM',
#  'NCT01474954: => BLOOD, HEART, AND CIRCULATION,INFECTIOUS DISEASES',
#  'NCT01478685: => CANCER,KIDNEYS AND URINARY SYSTEM,TUMORS',
#  'NCT01480440: => INJURIES,IMMUNE SYSTEM,BONES, JOINTS, AND MUSCLES',
#  'NCT01492374: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT01503515: => CANCER,INFECTIOUS DISEASES',
#  'NCT01518374: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT01519141: => INFECTIOUS DISEASES,BLOOD, HEART, AND CIRCULATION',
#  'NCT01525082: => CANCER,TUMORS',
#  'NCT01530659: => GENETICS AND BIRTH DEFECTS,EYES AND VISION',
#  'NCT01533636: => BLOOD, HEART, AND CIRCULATION,DIGESTIVE SYSTEM,INJURIES,LUNGS AND BREATHING',
#  'NCT01535235: => INFECTIOUS DISEASES,INJURIES,BLOOD, HEART, AND CIRCULATION,DIGESTIVE SYSTEM,LUNGS AND BREATHING',
#  'NCT01535508: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT01537393: => ORGAN AND TISSUE TRANSPLANT,SURGICAL STUDIES,EYES AND VISION',
#  'NCT01538095: => CANCER,BRAIN AND NERVES',
#  'NCT01540565: => CANCER,GENETICS AND BIRTH DEFECTS',
#  'NCT01553149: => CANCER,TUMORS',
#  'NCT01554371: => CANCER,BRAIN AND NERVES',
#  'NCT01559844: => CANCER,INFECTIOUS DISEASES',
#  'NCT01560377: => DIGESTIVE SYSTEM,CANCER',
#  'NCT01565941: => LUNGS AND BREATHING,BLOOD, HEART, AND CIRCULATION',
#  'NCT01568554: => GENETICS AND BIRTH DEFECTS,METABOLIC PROBLEMS',
#  'NCT01571596: => GENETICS AND BIRTH DEFECTS,METABOLIC PROBLEMS',
#  'NCT01571817: => ENDOCRINE SYSTEM,METABOLIC PROBLEMS',
#  'NCT01579292: => ENDOCRINE SYSTEM,METABOLIC PROBLEMS',
#  'NCT01581281: => BRAIN AND NERVES,BLOOD, HEART, AND CIRCULATION',
#  'NCT01592747: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT01592773: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT01592786: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT01596699: => IMMUNE SYSTEM,METABOLIC PROBLEMS,BONES, JOINTS, AND MUSCLES,CANCER',
#  'NCT01606306: => RESPIRATORY DISEASES,LUNGS AND BREATHING',
#  'NCT01606319: => RESPIRATORY DISEASES,LUNGS AND BREATHING',
#  'NCT01606501: => INJURIES,BONES, JOINTS, AND MUSCLES',
#  'NCT01619475: => DIGESTIVE SYSTEM,INFECTIOUS DISEASES',
#  'NCT01629095: => DIGESTIVE SYSTEM,ORGAN AND TISSUE TRANSPLANT,GENETICS AND BIRTH DEFECTS',
#  'NCT01638559: => ORGAN AND TISSUE TRANSPLANT,IMMUNE SYSTEM',
#  'NCT01643382: => ENDOCRINE SYSTEM,ORGAN AND TISSUE TRANSPLANT,KIDNEYS AND URINARY SYSTEM,METABOLIC PROBLEMS',
#  'NCT01648348: => CANCER,BRAIN AND NERVES',
#  'NCT01652157: => INJURIES,BLOOD, HEART, AND CIRCULATION,DIGESTIVE SYSTEM,LUNGS AND BREATHING',
#  'NCT01672853: => INJURIES,BLOOD, HEART, AND CIRCULATION,DIGESTIVE SYSTEM,LUNGS AND BREATHING',
#  'NCT01681693: => ENDOCRINE SYSTEM,METABOLIC PROBLEMS',
#  'NCT01687153: => BRAIN AND NERVES,INJURIES,MENTAL HEALTH',
#  'NCT01688895: => GENETICS AND BIRTH DEFECTS,METABOLIC PROBLEMS',
#  'NCT01709435: => CANCER,TUMORS,BRAIN AND NERVES',
#  'NCT01713764: => ENDOCRINE SYSTEM,METABOLIC PROBLEMS',
#  'NCT01718990: => BLOOD, HEART, AND CIRCULATION,DIGESTIVE SYSTEM,INJURIES,LUNGS AND BREATHING',
#  'NCT01723826: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT01739933: => BRAIN AND NERVES,MENTAL HEALTH,INFECTIOUS DISEASES',
#  'NCT01748721: => CANCER,BLOOD, HEART, AND CIRCULATION',
#  'NCT01766817: => BLOOD, HEART, AND CIRCULATION,DIGESTIVE SYSTEM,INJURIES,LUNGS AND BREATHING',
#  'NCT01769196: => BLOOD, HEART, AND CIRCULATION,DIGESTIVE SYSTEM,INJURIES,LUNGS AND BREATHING',
#  'NCT01772680: => ENDOCRINE SYSTEM,BLOOD, HEART, AND CIRCULATION,METABOLIC PROBLEMS',
#  'NCT01773707: => ENDOCRINE SYSTEM,METABOLIC PROBLEMS',
#  'NCT01781975: => ENDOCRINE SYSTEM,METABOLIC PROBLEMS',
#  'NCT01784419: => BLOOD, HEART, AND CIRCULATION,DIGESTIVE SYSTEM,INJURIES,LUNGS AND BREATHING',
#  'NCT01793233: => CANCER,BLOOD, HEART, AND CIRCULATION',
#  'NCT01793441: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT01802216: => MOUTH AND TEETH,KIDNEYS AND URINARY SYSTEM',
#  'NCT01804829: => ORGAN AND TISSUE TRANSPLANT,INFECTIOUS DISEASES,DIGESTIVE SYSTEM,CANCER',
#  'NCT01811550: => BRAIN AND NERVES,METABOLIC PROBLEMS',
#  'NCT01814813: => CANCER,BRAIN AND NERVES',
#  'NCT01817075: => CANCER,TUMORS,INFECTIOUS DISEASES',
#  'NCT01824875: => CANCER,TUMORS',
#  'NCT01825681: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT01841307: => ORGAN AND TISSUE TRANSPLANT,INJURIES,BLOOD, HEART, AND CIRCULATION,DIGESTIVE SYSTEM,LUNGS AND BREATHING',
#  'NCT01842581: => DIGESTIVE SYSTEM,BRAIN AND NERVES',
#  'NCT01858012: => INFECTIOUS DISEASES,METABOLIC PROBLEMS',
#  'NCT01872689: => BLOOD, HEART, AND CIRCULATION,DIGESTIVE SYSTEM,INJURIES,LUNGS AND BREATHING',
#  'NCT01877655: => ORGAN AND TISSUE TRANSPLANT,INFECTIOUS DISEASES',
#  'NCT01878253: => IMMUNE SYSTEM,BONES, JOINTS, AND MUSCLES',
#  'NCT01891383: => BRAIN AND NERVES,INJURIES,MENTAL HEALTH',
#  'NCT01892969: => LUNGS AND BREATHING,BLOOD, HEART, AND CIRCULATION',
#  'NCT01893996: => IMMUNE SYSTEM,BLOOD, HEART, AND CIRCULATION',
#  'NCT01896869: => CANCER,TUMORS',
#  'NCT01900665: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT01911442: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT01912378: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT01914393: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT01919476: => ENDOCRINE SYSTEM,METABOLIC PROBLEMS',
#  'NCT01920061: => CANCER,TUMORS',
#  'NCT01928329: => ENDOCRINE SYSTEM,METABOLIC PROBLEMS',
#  'NCT01938430: => DIGESTIVE SYSTEM,ORGAN AND TISSUE TRANSPLANT,INFECTIOUS DISEASES',
#  'NCT01938807: => ENDOCRINE SYSTEM,METABOLIC PROBLEMS',
#  'NCT01945775: => CANCER,GENETICS AND BIRTH DEFECTS',
#  'NCT01946139: => CANCER,INFECTIOUS DISEASES',
#  'NCT01950819: => ORGAN AND TISSUE TRANSPLANT,KIDNEYS AND URINARY SYSTEM',
#  'NCT01958320: => DIGESTIVE SYSTEM,FETUS OR NEWBORN DISORDERS,SURGICAL STUDIES,BLOOD, HEART, AND CIRCULATION',
#  'NCT01964430: => TUMORS,ENDOCRINE SYSTEM,DIGESTIVE SYSTEM,CANCER',
#  'NCT01966419: => DIGESTIVE SYSTEM,BRAIN AND NERVES',
#  'NCT01966666: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT01967992: => ENDOCRINE SYSTEM,METABOLIC PROBLEMS',
#  'NCT01982968: => BLOOD, HEART, AND CIRCULATION,DIGESTIVE SYSTEM,INJURIES,LUNGS AND BREATHING',
#  'NCT01988688: => BRAIN AND NERVES,EAR, NOSE, AND THROAT',
#  'NCT01994889: => GENETICS AND BIRTH DEFECTS,BLOOD, HEART, AND CIRCULATION',
#  'NCT01997008: => MENTAL HEALTH,INFECTIOUS DISEASES',
#  'NCT01999894: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT02002819: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT02016560: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT02023918: => ENDOCRINE SYSTEM,METABOLIC PROBLEMS',
#  'NCT02034916: => CANCER,GENETICS AND BIRTH DEFECTS',
#  'NCT02038764: => ENDOCRINE SYSTEM,METABOLIC PROBLEMS',
#  'NCT02049307: => INFECTIOUS DISEASES,INJURIES,BLOOD, HEART, AND CIRCULATION,DIGESTIVE SYSTEM,LUNGS AND BREATHING',
#  'NCT02052778: => CANCER,BRAIN AND NERVES',
#  'NCT02059408: => KIDNEYS AND URINARY SYSTEM,BLOOD, HEART, AND CIRCULATION',
#  'NCT02059499: => INFECTIOUS DISEASES,CANCER,TUMORS',
#  'NCT02071862: => CANCER,TUMORS',
#  'NCT02075710: => BLOOD, HEART, AND CIRCULATION,METABOLIC PROBLEMS',
#  'NCT02075775: => INJURIES,BONES, JOINTS, AND MUSCLES',
#  'NCT02078934: => METABOLIC PROBLEMS,BONES, JOINTS, AND MUSCLES',
#  'NCT02081755: => ORGAN AND TISSUE TRANSPLANT,CANCER',
#  'NCT02095132: => CANCER,BRAIN AND NERVES,TUMORS',
#  'NCT02116777: => CANCER,TUMORS,BRAIN AND NERVES',
#  'NCT02117713: => MULTISYSTEM DISORDERS,DIGESTIVE SYSTEM',
#  'NCT02120794: => ENDOCRINE SYSTEM,METABOLIC PROBLEMS',
#  'NCT02133846: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT02135042: => CANCER,INFECTIOUS DISEASES',
#  'NCT02135419: => INFECTIOUS DISEASES,CANCER,TUMORS',
#  'NCT02139306: => BLOOD, HEART, AND CIRCULATION,DIGESTIVE SYSTEM,INJURIES,LUNGS AND BREATHING',
#  'NCT02139722: => DIGESTIVE SYSTEM,INFECTIOUS DISEASES',
#  'NCT02149160: => BRAIN AND NERVES,GENETICS AND BIRTH DEFECTS,MENTAL HEALTH',
#  'NCT02163577: => GENETICS AND BIRTH DEFECTS,METABOLIC PROBLEMS',
#  'NCT02175732: => ENDOCRINE SYSTEM,METABOLIC PROBLEMS',
#  'NCT02177760: => ORGAN AND TISSUE TRANSPLANT,IMMUNE SYSTEM',
#  'NCT02180867: => CANCER,TUMORS',
#  'NCT02213458: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT02215200: => ENDOCRINE SYSTEM,METABOLIC PROBLEMS',
#  'NCT02219269: => ENDOCRINE SYSTEM,METABOLIC PROBLEMS,CANCER,BLOOD, HEART, AND CIRCULATION,BRAIN AND NERVES',
#  'NCT02240420: => ENDOCRINE SYSTEM,METABOLIC PROBLEMS',
#  'NCT02244801: => ORGAN AND TISSUE TRANSPLANT,KIDNEYS AND URINARY SYSTEM',
#  'NCT02250651: => EYES AND VISION,BLOOD, HEART, AND CIRCULATION',
#  'NCT02257203: => MOUTH AND TEETH,METABOLIC PROBLEMS',
#  'NCT02272946: => BLOOD, HEART, AND CIRCULATION,INFECTIOUS DISEASES',
#  'NCT02278939: => ENDOCRINE SYSTEM,METABOLIC PROBLEMS',
#  'NCT02290184: => ENDOCRINE SYSTEM,METABOLIC PROBLEMS',
#  'NCT02293837: => ENDOCRINE SYSTEM,METABOLIC PROBLEMS',
#  'NCT02302209: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT02304458: => CANCER,TUMORS',
#  'NCT02312687: => GENETICS AND BIRTH DEFECTS,METABOLIC PROBLEMS',
#  'NCT02319369: => CANCER,BLOOD, HEART, AND CIRCULATION',
#  'NCT02323880: => CANCER,BRAIN AND NERVES',
#  'NCT02333942: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT02344290: => BLOOD, HEART, AND CIRCULATION,INFECTIOUS DISEASES',
#  'NCT02350127: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT02350634: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT02353598: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT02365922: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT02367092: => DIGESTIVE SYSTEM,ORGAN AND TISSUE TRANSPLANT,BONES, JOINTS, AND MUSCLES',
#  'NCT02372773: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT02375204: => CANCER,TUMORS',
#  'NCT02381457: => GENETICS AND BIRTH DEFECTS,IMMUNE SYSTEM,MENTAL HEALTH,METABOLIC PROBLEMS,BRAIN AND NERVES',
#  'NCT02386111: => CANCER,TUMORS,KIDNEYS AND URINARY SYSTEM',
#  'NCT02390011: => CANCER,TUMORS',
#  'NCT02402244: => CANCER,BRAIN AND NERVES',
#  'NCT02402439: => ENDOCRINE SYSTEM,METABOLIC PROBLEMS',
#  'NCT02403752: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT02408861: => INFECTIOUS DISEASES,CANCER,TUMORS',
#  'NCT02410902: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT02429869: => ORGAN AND TISSUE TRANSPLANT,INFECTIOUS DISEASES',
#  'NCT02432209: => METABOLIC PROBLEMS,REPRODUCTIVE HEALTH',
#  'NCT02437851: => CANCER,INFECTIOUS DISEASES',
#  'NCT02440685: => CANCER,TUMORS',
#  'NCT02446600: => CANCER,GENETICS AND BIRTH DEFECTS',
#  'NCT02456103: => BLOOD, HEART, AND CIRCULATION,DIGESTIVE SYSTEM,INJURIES,LUNGS AND BREATHING',
#  'NCT02458235: => CANCER,BLOOD, HEART, AND CIRCULATION',
#  'NCT02466516: => BLOOD, HEART, AND CIRCULATION,DIGESTIVE SYSTEM,INJURIES,LUNGS AND BREATHING',
#  'NCT02477800: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT02482233: => DRUG DEPENDENCE AND RELATED DISORDERS,SURGICAL STUDIES',
#  'NCT02492711: => CANCER,TUMORS',
#  'NCT02502266: => CANCER,GENETICS AND BIRTH DEFECTS',
#  'NCT02523014: => CANCER,TUMORS',
#  'NCT02524106: => BLOOD, HEART, AND CIRCULATION,INFECTIOUS DISEASES,METABOLIC PROBLEMS',
#  'NCT02526160: => GENETICS AND BIRTH DEFECTS,METABOLIC PROBLEMS',
#  'NCT02533934: => DIGESTIVE SYSTEM,ORGAN AND TISSUE TRANSPLANT,INFECTIOUS DISEASES',
#  'NCT02537431: => GENETICS AND BIRTH DEFECTS,METABOLIC PROBLEMS',
#  'NCT02543645: => CANCER,TUMORS,KIDNEYS AND URINARY SYSTEM',
#  'NCT02545049: => ENDOCRINE SYSTEM,KIDNEYS AND URINARY SYSTEM,METABOLIC PROBLEMS',
#  'NCT02548351: => BLOOD, HEART, AND CIRCULATION,DIGESTIVE SYSTEM,INJURIES,LUNGS AND BREATHING',
#  'NCT02548598: => LUNGS AND BREATHING,EAR, NOSE, AND THROAT',
#  'NCT02550873: => BLOOD, HEART, AND CIRCULATION,DIGESTIVE SYSTEM,INJURIES,LUNGS AND BREATHING',
#  'NCT02553941: => CANCER,BLOOD, HEART, AND CIRCULATION',
#  'NCT02564198: => CANCER,TUMORS',
#  'NCT02566356: => BRAIN AND NERVES,DIAGNOSTIC TESTS,MENTAL HEALTH',
#  'NCT02567032: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT02568267: => CANCER,TUMORS,BRAIN AND NERVES',
#  'NCT02568709: => BRAIN AND NERVES,DIAGNOSTIC TESTS,MENTAL HEALTH',
#  'NCT02569060: => ENDOCRINE SYSTEM,METABOLIC PROBLEMS',
#  'NCT02570321: => DIGESTIVE SYSTEM,EYES AND VISION,INFECTIOUS DISEASES',
#  'NCT02577575: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT02580877: => ENDOCRINE SYSTEM,METABOLIC PROBLEMS',
#  'NCT02595866: => CANCER,TUMORS,INFECTIOUS DISEASES',
#  'NCT02595931: => CANCER,TUMORS',
#  'NCT02597933: => INJURIES,BLOOD, HEART, AND CIRCULATION,DIGESTIVE SYSTEM,LUNGS AND BREATHING',
#  'NCT02601937: => CANCER,TUMORS',
#  'NCT02601950: => CANCER,TUMORS',
#  'NCT02602327: => DIGESTIVE SYSTEM,CANCER',
#  'NCT02613260: => CANCER,TUMORS',
#  'NCT02630316: => INJURIES,BLOOD, HEART, AND CIRCULATION,DIGESTIVE SYSTEM,LUNGS AND BREATHING',
#  'NCT02633293: => INJURIES,BLOOD, HEART, AND CIRCULATION,DIGESTIVE SYSTEM,LUNGS AND BREATHING',
#  'NCT02638701: => CANCER,BRAIN AND NERVES,TUMORS,BLOOD, HEART, AND CIRCULATION',
#  'NCT02646839: => CANCER,BLOOD, HEART, AND CIRCULATION',
#  'NCT02649959: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT02650401: => CANCER,BRAIN AND NERVES',
#  'NCT02654743: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT02667587: => CANCER,BRAIN AND NERVES',
#  'NCT02670083: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT02673489: => DIGESTIVE SYSTEM,INFECTIOUS DISEASES',
#  'NCT02677116: => CANCER,TUMORS',
#  'NCT02677831: => BLOOD, HEART, AND CIRCULATION,METABOLIC PROBLEMS',
#  'NCT02684838: => CANCER,BRAIN AND NERVES',
#  'NCT02691247: => ENDOCRINE SYSTEM,METABOLIC PROBLEMS',
#  'NCT02700945: => BRAIN AND NERVES,BLOOD, HEART, AND CIRCULATION',
#  'NCT02704403: => BLOOD, HEART, AND CIRCULATION,DIGESTIVE SYSTEM,INJURIES,LUNGS AND BREATHING',
#  'NCT02710214: => BRAIN AND NERVES,REPRODUCTIVE HEALTH',
#  'NCT02725658: => CANCER,TUMORS',
#  'NCT02729311: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT02734277: => ENDOCRINE SYSTEM,METABOLIC PROBLEMS',
#  'NCT02741323: => ORGAN AND TISSUE TRANSPLANT,KIDNEYS AND URINARY SYSTEM,INFECTIOUS DISEASES',
#  'NCT02744092: => CANCER,BLOOD, HEART, AND CIRCULATION',
#  'NCT02758808: => INJURIES,BLOOD, HEART, AND CIRCULATION,DIGESTIVE SYSTEM,LUNGS AND BREATHING',
#  'NCT02772679: => ENDOCRINE SYSTEM,METABOLIC PROBLEMS',
#  'NCT02775305: => KIDNEYS AND URINARY SYSTEM,BONES, JOINTS, AND MUSCLES',
#  'NCT02780804: => CANCER,TUMORS,BRAIN AND NERVES',
#  'NCT02781675: => BLOOD, HEART, AND CIRCULATION,METABOLIC PROBLEMS',
#  'NCT02783495: => CANCER,BRAIN AND NERVES',
#  'NCT02783573: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT02791230: => GENETICS AND BIRTH DEFECTS,BLOOD, HEART, AND CIRCULATION',
#  'NCT02797470: => CANCER,INFECTIOUS DISEASES',
#  'NCT02808650: => CANCER,TUMORS,BRAIN AND NERVES',
#  'NCT02834923: => ENDOCRINE SYSTEM,METABOLIC PROBLEMS',
#  'NCT02844439: => CANCER,BRAIN AND NERVES',
#  'NCT02846233: => ENDOCRINE SYSTEM,METABOLIC PROBLEMS',
#  'NCT02846324: => BLOOD, HEART, AND CIRCULATION,DIGESTIVE SYSTEM,INJURIES,LUNGS AND BREATHING',
#  'NCT02846545: => ENDOCRINE SYSTEM,METABOLIC PROBLEMS',
#  'NCT02854033: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT02860039: => CANCER,INFECTIOUS DISEASES',
#  'NCT02867592: => CANCER,TUMORS,BRAIN AND NERVES',
#  'NCT02880956: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT02901431: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT02909777: => CANCER,BRAIN AND NERVES',
#  'NCT02915705: => GENETICS AND BIRTH DEFECTS,METABOLIC PROBLEMS',
#  'NCT02922751: => MULTISYSTEM DISORDERS,GENETICS AND BIRTH DEFECTS,INJURIES,BLOOD, HEART, AND CIRCULATION,DIGESTIVE SYSTEM,FETUS OR NEWBORN DISORDERS,LUNGS AND BREATHING',
#  'NCT02936401: => INFECTIOUS DISEASES,BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT02950467: => INFECTIOUS DISEASES,MENTAL HEALTH',
#  'NCT02956642: => ENDOCRINE SYSTEM,METABOLIC PROBLEMS',
#  'NCT02975505: => BLOOD, HEART, AND CIRCULATION,KIDNEYS AND URINARY SYSTEM',
#  'NCT02979249: => GENETICS AND BIRTH DEFECTS,METABOLIC PROBLEMS',
#  'NCT03022682: => ENDOCRINE SYSTEM,METABOLIC PROBLEMS',
#  'NCT03028740: => BLOOD, HEART, AND CIRCULATION,DIGESTIVE SYSTEM,INJURIES,LUNGS AND BREATHING',
#  'NCT03040713: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT03040999: => CANCER,TUMORS',
#  'NCT03053050: => BLOOD, HEART, AND CIRCULATION,DIGESTIVE SYSTEM,INJURIES,LUNGS AND BREATHING',
#  'NCT03076671: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT03085524: => ENDOCRINE SYSTEM,BLOOD, HEART, AND CIRCULATION,METABOLIC PROBLEMS',
#  'NCT03088956: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT03092050: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT03114657: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT03150719: => BLOOD, HEART, AND CIRCULATION,DIGESTIVE SYSTEM,INJURIES,LUNGS AND BREATHING',
#  'NCT03155620: => CANCER,TUMORS,BRAIN AND NERVES',
#  'NCT03157167: => CANCER,INFECTIOUS DISEASES',
#  'NCT03160027: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT03160326: => KIDNEYS AND URINARY SYSTEM,BONES, JOINTS, AND MUSCLES',
#  'NCT03190915: => CANCER,TUMORS',
#  'NCT03207711: => ENDOCRINE SYSTEM,METABOLIC PROBLEMS',
#  'NCT03207945: => BLOOD, HEART, AND CIRCULATION,INFECTIOUS DISEASES,METABOLIC PROBLEMS',
#  'NCT03210714: => CANCER,TUMORS,BRAIN AND NERVES',
#  'NCT03213652: => CANCER,TUMORS,BRAIN AND NERVES',
#  'NCT03213665: => CANCER,TUMORS,BRAIN AND NERVES',
#  'NCT03213678: => CANCER,TUMORS,BRAIN AND NERVES',
#  'NCT03213691: => CANCER,TUMORS,BRAIN AND NERVES',
#  'NCT03213704: => CANCER,TUMORS,BRAIN AND NERVES',
#  'NCT03217058: => MENTAL HEALTH,INFECTIOUS DISEASES',
#  'NCT03219164: => BLOOD, HEART, AND CIRCULATION,DIGESTIVE SYSTEM,INJURIES,LUNGS AND BREATHING',
#  'NCT03220035: => CANCER,TUMORS,BRAIN AND NERVES',
#  'NCT03228290: => DIGESTIVE SYSTEM,ORGAN AND TISSUE TRANSPLANT',
#  'NCT03233204: => GENETICS AND BIRTH DEFECTS,TUMORS,BRAIN AND NERVES,CANCER',
#  'NCT03243058: => ENDOCRINE SYSTEM,METABOLIC PROBLEMS',
#  'NCT03256539: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT03260920: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT03277573: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT03284385: => CANCER,TUMORS',
#  'NCT03288545: => CANCER,KIDNEYS AND URINARY SYSTEM,TUMORS',
#  'NCT03316274: => CANCER,IMMUNE SYSTEM,INFECTIOUS DISEASES',
#  'NCT03325426: => KIDNEYS AND URINARY SYSTEM,BLOOD, HEART, AND CIRCULATION',
#  'NCT03330197: => CANCER,BRAIN AND NERVES',
#  'NCT03330587: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT03333655: => CANCER,TUMORS',
#  'NCT03334175: => ENDOCRINE SYSTEM,METABOLIC PROBLEMS',
#  'NCT03338816: => GENETICS AND BIRTH DEFECTS,METABOLIC PROBLEMS',
#  'NCT03349918: => MENTAL HEALTH,BLOOD, HEART, AND CIRCULATION',
#  'NCT03351465: => MENTAL HEALTH,REPRODUCTIVE HEALTH',
#  'NCT03373110: => MENTAL HEALTH,BLOOD, HEART, AND CIRCULATION',
#  'NCT03376893: => BRAIN AND NERVES,BLOOD, HEART, AND CIRCULATION',
#  'NCT03377361: => CANCER,TUMORS',
#  'NCT03380091: => MENTAL HEALTH,METABOLIC PROBLEMS',
#  'NCT03405662: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT03469986: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT03473509: => KIDNEYS AND URINARY SYSTEM,BLOOD, HEART, AND CIRCULATION',
#  'NCT03490253: => ENDOCRINE SYSTEM,MENTAL HEALTH,METABOLIC PROBLEMS',
#  'NCT03491150: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT03496545: => BRAIN AND NERVES,INJURIES',
#  'NCT03500315: => ORGAN AND TISSUE TRANSPLANT,INFECTIOUS DISEASES',
#  'NCT03504917: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT03518073: => BRAIN AND NERVES,MENTAL HEALTH',
#  'NCT03525431: => BRAIN AND NERVES,MENTAL HEALTH,METABOLIC PROBLEMS',
#  'NCT03534141: => ORGAN AND TISSUE TRANSPLANT,INFECTIOUS DISEASES,INJURIES,DIGESTIVE SYSTEM,CANCER,KIDNEYS AND URINARY SYSTEM',
#  'NCT03538301: => BLOOD, HEART, AND CIRCULATION,DIGESTIVE SYSTEM,INJURIES,LUNGS AND BREATHING',
#  'NCT03546322: => CANCER,TUMORS']
